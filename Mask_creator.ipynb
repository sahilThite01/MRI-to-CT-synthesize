# %%
# Import the torch library
import torch

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Bases code of Mask creation like :
#  ### 1. MRI based Mask creation
#  ### 2. CT based Mask creation
#  ### 3. Union based Mask creation
#  ### 4. Intersection based Mask creation

# %%
# import os
# import nibabel as nib
# import numpy as np
# import SimpleITK as sitk
# from skimage import morphology
# from scipy.ndimage import binary_fill_holes

# # Define the base and output directories
# base_dir = r'D:/Project/code/Task1/brain'
# output_dir = r'D:/Project/code/Task1/brain'
# # base_dir = r'D:\Project\code\Task1\pelvis'
# # output_dir = r'D:\Project\code\Task1\pelvis'

# def create_masks(mri_path, ct_path, output_path):
#     try:
#         print(".")
#         # Load MRI and CT images
#         mri_img = nib.load(mri_path)
#         ct_img = nib.load(ct_path)
        
#         mri_data = mri_img.get_fdata()
#         ct_data = ct_img.get_fdata()

#         # Threshold MRI and CT images
#         mri_threshold = sitk.OtsuThreshold(sitk.GetImageFromArray(mri_data), 0, 1)
#         ct_threshold = sitk.OtsuThreshold(sitk.GetImageFromArray(ct_data), 0, 1)

#         mri_mask = sitk.GetArrayFromImage(mri_threshold) > 0
#         ct_mask = sitk.GetArrayFromImage(ct_threshold) > 0

#         # Fill holes and remove small objects for MRI and CT masks
#         mri_mask = morphology.remove_small_objects(binary_fill_holes(mri_mask), min_size=64)
#         ct_mask = morphology.remove_small_objects(binary_fill_holes(ct_mask), min_size=64)

#         # Create union mask
#         union_mask = np.logical_or(mri_mask, ct_mask)

#         # Create intersection mask
#         intersection_mask = np.logical_and(mri_mask, ct_mask)

#         # Save the masks as NIfTI files
#         mask_filenames = {
#             'mri_mask.nii.gz': mri_mask,
#             'ct_mask.nii.gz': ct_mask,
#             'union_mask.nii.gz': union_mask,
#             'intersection_mask.nii.gz': intersection_mask
#         }

#         for filename, mask_data in mask_filenames.items():
#             output_filepath = os.path.join(output_path, filename)
#             mask_img = nib.Nifti1Image(mask_data.astype(np.float32), affine=mri_img.affine)
#             nib.save(mask_img, output_filepath)

#         print(f"Masks created and saved to {output_path}")

#     except Exception as e:
#         print(f"An error occurred: {e}")

# # Loop through all patient directories
# for patient_dir in os.listdir(base_dir):
#     patient_path = os.path.join(base_dir, patient_dir)
#     if os.path.isdir(patient_path):
#         mri_path = os.path.join(patient_path, 'mr.nii.gz')
#         ct_path = os.path.join(patient_path, 'ct.nii.gz')
#         output_path = os.path.join(output_dir, patient_dir)

#         # Check if the files exist before processing
#         if os.path.exists(mri_path) and os.path.exists(ct_path):
#             # Create output directory if it doesn't exist
#             if not os.path.exists(output_path):
#                 os.makedirs(output_path)

#             # Create masks
#             create_masks(mri_path, ct_path, output_path)
#         else:
#             print(f"Skipping {patient_dir} due to missing files.")
#             if not os.path.exists(mri_path):
#                 print(f"Missing file: {mri_path}")
#             if not os.path.exists(ct_path):
#                 print(f"Missing file: {ct_path}")

# print("Mask creation completed.")
# Out:
# .
# Masks created and saved to D:\Project\code\Task1\brain\1BA001
# .
# Masks created and saved to D:\Project\code\Task1\brain\1BA005
# Mask creation completed.

# %% [markdown]
# UNION MASKS ONLY

# %%
import os
import nibabel as nib
import numpy as np
import SimpleITK as sitk
from skimage import morphology
from scipy.ndimage import binary_fill_holes

# Define the base and output directories
# C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain
base_dir = r'C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain'
output_dir = r'C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain'
# base_dir = r'D:\Project\code\Task1\pelvis'
# output_dir = r'D:\Project\code\Task1\pelvis'

def create_union_mask(mri_path, ct_path, output_path):
    try:
        print(".")
        # Load MRI and CT images
        mri_img = nib.load(mri_path)
        ct_img = nib.load(ct_path)
        
        mri_data = mri_img.get_fdata()
        ct_data = ct_img.get_fdata()

        # Threshold MRI and CT images
        mri_threshold = sitk.OtsuThreshold(sitk.GetImageFromArray(mri_data), 0, 1)
        ct_threshold = sitk.OtsuThreshold(sitk.GetImageFromArray(ct_data), 0, 1)

        mri_mask = sitk.GetArrayFromImage(mri_threshold) > 0
        ct_mask = sitk.GetArrayFromImage(ct_threshold) > 0

        # Fill holes and remove small objects for MRI and CT masks
        mri_mask = morphology.remove_small_objects(binary_fill_holes(mri_mask), min_size=64)
        ct_mask = morphology.remove_small_objects(binary_fill_holes(ct_mask), min_size=64)

        # Create union mask
        union_mask = np.logical_or(mri_mask, ct_mask)

        # Save the union mask as a NIfTI file
        union_mask_filepath = os.path.join(output_path, 'union_mask.nii.gz')
        union_mask_img = nib.Nifti1Image(union_mask.astype(np.float32), affine=mri_img.affine)
        nib.save(union_mask_img, union_mask_filepath)

        print(f"Union mask created and saved to {union_mask_filepath}")

    except Exception as e:
        print(f"An error occurred: {e}")

# Loop through all patient directories
for patient_dir in os.listdir(base_dir):
    patient_path = os.path.join(base_dir, patient_dir)
    if os.path.isdir(patient_path):
        mri_path = os.path.join(patient_path, 'mr.nii.gz')
        ct_path = os.path.join(patient_path, 'ct.nii.gz')
        output_path = os.path.join(output_dir, patient_dir)

        # Check if the files exist before processing
        if os.path.exists(mri_path) and os.path.exists(ct_path):
            # Create output directory if it doesn't exist
            if not os.path.exists(output_path):
                os.makedirs(output_path)

            # Create union mask
            create_union_mask(mri_path, ct_path, output_path)
        else:
            print(f"Skipping {patient_dir} due to missing files.")
            if not os.path.exists(mri_path):
                print(f"Missing file: {mri_path}")
            if not os.path.exists(ct_path):
                print(f"Missing file: {ct_path}")

print("Union mask creation completed.")
# Out:
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA001\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA005\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA012\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA014\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA022\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA032\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA040\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA054\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA058\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA075\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA076\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA082\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA085\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA091\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA097\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA100\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA103\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA105\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA111\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA116\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA125\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA131\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA141\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA143\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA151\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA158\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA159\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA164\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA172\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA175\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA184\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA185\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA189\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA201\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA206\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA220\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA222\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA227\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA234\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA239\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA247\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA253\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA256\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA260\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA266\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA278\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA288\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA292\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA294\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA300\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA305\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA307\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA325\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA328\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA336\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA345\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA358\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA359\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA368\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BA379\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB002\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB003\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB005\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB006\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB007\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB008\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB011\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB016\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB017\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB026\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB028\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB030\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB031\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB033\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB034\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB039\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB041\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB043\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB044\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB048\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB049\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB050\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB051\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB052\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB059\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB062\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB066\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB071\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB072\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB073\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB075\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB076\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB079\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB082\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB083\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB085\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB090\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB091\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB095\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB096\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB098\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB099\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB100\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB102\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB109\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB111\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB145\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB151\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB152\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB171\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB173\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB175\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB177\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB179\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB182\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB184\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB189\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB198\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB200\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BB205\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC001\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC004\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC006\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC007\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC008\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC009\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC010\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC014\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC017\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC019\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC020\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC021\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC022\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC023\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC025\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC027\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC028\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC031\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC034\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC035\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC036\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC037\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC038\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC039\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC041\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC046\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC047\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC048\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC049\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC050\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC051\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC052\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC053\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC054\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC056\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC058\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC062\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC063\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC064\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC065\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC066\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC067\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC068\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC070\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC073\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC074\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC075\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC076\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC077\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC080\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC081\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC082\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC083\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC084\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC085\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC086\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC087\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC088\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC090\union_mask.nii.gz
# .
# Union mask created and saved to C:\Users\DELL\Desktop\BE Project - Shruti ,Rajat, Sahil ,Sakshi\Task1\brain\1BC094\union_mask.nii.gz
# Union mask creation completed.
